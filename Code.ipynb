# %%
import pandas as pd
lse_dat=pd.read_excel('./data/LSE_dat.xlsx', sheet_name="Teaching")
lse_dat.columns = lse_dat.iloc[0]
lse_dat = lse_dat[1:]
lse_dat
# Out:
# 0    Mode of study      Level of study Subject level Subject code     Subject  \
# 1        All modes  All undergraduates          CAH1        CAH04  Psychology
# 2        All modes  All undergraduates          CAH1        CAH04  Psychology
# 3        All modes  All undergraduates          CAH1        CAH04  Psychology
# 4        All modes  All undergraduates          CAH1        CAH04  Psychology
# 5        All modes  All undergraduates          CAH1        CAH04  Psychology
# ...            ...                 ...           ...          ...         ...
# 4892     Full-time        First degree  All subjects          NaN         NaN
# 4893     Full-time        First degree  All subjects          NaN         NaN
# 4894     Full-time        First degree  All subjects          NaN         NaN
# 4895     Full-time        First degree  All subjects          NaN         NaN
# 4896     Full-time        First degree  All subjects          NaN         NaN
#
# ...
